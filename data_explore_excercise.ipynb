# %%
# imports

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import acquire as a
import wrangle as w
import prepare as p

# %%
store_df = w.acquire_store()
store_df = p.prep_store()

# %%
store_df.head()
# Out:
#             sale_amount  item_brand  \
# sale_date
# 2013-01-01           13    Riceland
# 2013-01-01           26     Mueller
# 2013-01-01           27  Mama Marys
# 2013-01-01           54     Mueller
# 2013-01-01           35     Mueller
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01                                        Pizza Sauce        4.65
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
#
#                      store_address  store_zipcode    month day_of_week  \
# sale_date
# 2013-01-01  12125 Alamo Ranch Pkwy          78253  January     Tuesday
# 2013-01-01  12018 Perrin Beitel Rd          78217  January     Tuesday
# ...

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 913000 entries, 2013-01-01 to 2017-12-31
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   sale_amount    913000 non-null  int64
#  1   item_brand     913000 non-null  object
#  2   item_name      913000 non-null  object
#  3   item_price     913000 non-null  float64
#  4   store_address  913000 non-null  object
#  5   store_zipcode  913000 non-null  int64
#  6   month          913000 non-null  object
#  7   day_of_week    913000 non-null  object
#  8   sales_total    913000 non-null  float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 69.7+ MB

# %%
store_df.shape
# Out:
# (913000, 9)

# %%
store_df.index.nunique()
# Out:
# 1826

# %%
store_df.index.year
# Out:
# Int64Index([2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013,
#             ...
#             2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017],
#            dtype='int64', name='sale_date', length=913000)

# %%
store_df.resample('y').mean()
# Out:
#             sale_amount  item_price  store_zipcode  sales_total
# sale_date
# 2013-12-31    43.513660      5.1604        78224.8   233.966480
# 2014-12-31    50.057436      5.1604        78224.8   269.111126
# 2015-12-31    52.256915      5.1604        78224.8   280.971482
# 2016-12-31    56.596503      5.1604        78224.8   304.233161
# 2017-12-31    58.815014      5.1604        78224.8   316.148154

# %%
train = store_df.loc[:'2015']
print(train.shape)
train
# Out:
# (547500, 9)
#             sale_amount          item_brand  \
# sale_date
# 2013-01-01           13            Riceland
# 2013-01-01           26             Mueller
# 2013-01-01           27          Mama Marys
# 2013-01-01           54             Mueller
# 2013-01-01           35             Mueller
# ...                 ...                 ...
# 2015-12-31           63     The First Years
# 2015-12-31           62       Lea & Perrins
# 2015-12-31           52               Ahold
# 2015-12-31           28  Moms Best Naturals
# 2015-12-31           23               Halls
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01                                        Pizza Sauce        4.65
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# ...

# %%
validate = store_df.loc['2016']
print(validate.shape)
validate
# Out:
# (183000, 9)
#             sale_amount          item_brand  \
# sale_date
# 2016-01-01           58              Choice
# 2016-01-01           34          Mama Marys
# 2016-01-01           69    Sundown Naturals
# 2016-01-01           30            Easy-off
# 2016-01-01           70        Usda Produce
# ...                 ...                 ...
# 2016-12-31           60              Scotch
# 2016-12-31           31  Moms Best Naturals
# 2016-12-31           41        Sally Hansen
# 2016-12-31           17          Boars Head
# 2016-12-31           74     The First Years
#
#                                                     item_name  item_price  \
# sale_date
# 2016-01-01  Choice Organic Teas Black Tea Classic Black - ...        5.20
# 2016-01-01                                        Pizza Sauce        4.65
# 2016-01-01  Sundown Naturals Essential Electrolytes Tropic...        3.45
# 2016-01-01                  Easy-off Oven Cleaner Lemon Scent        9.54
# ...

# %%
test = store_df.loc['2017']
print(test.shape)
test
# Out:
# (182500, 9)
#             sale_amount       item_brand  \
# sale_date
# 2017-01-01           18           Morton
# 2017-01-01           36         Munchies
# 2017-01-01           38       Mama Marys
# 2017-01-01           43            Heinz
# 2017-01-01           66      Natures Way
# ...                 ...              ...
# 2017-12-31           21            Halls
# 2017-12-31           32            Halls
# 2017-12-31           55      Natures Way
# 2017-12-31          100  The First Years
# 2017-12-31           82           Choice
#
#                                                     item_name  item_price  \
# sale_date
# 2017-01-01                          Morton Kosher Salt Coarse        6.01
# 2017-01-01  Munchies Sandwich Crackers Cheddar Cheese On G...        9.02
# 2017-01-01                                        Pizza Sauce        4.65
# 2017-01-01                        Heinz Tomato Ketchup - 2 Ct        8.65
# ...

# %%
y = train.sales_total
y.head()
# Out:
# sale_date
# 2013-01-01     10.92
# 2013-01-01    218.40
# 2013-01-01    125.55
# 2013-01-01    453.60
# 2013-01-01    294.00
# Name: sales_total, dtype: float64

# %%
sns.histplot(y)
plt.show()

# %%
y.plot()
# Out:
# <AxesSubplot:xlabel='sale_date'>

# %%
y.resample('Y').mean().plot()
# Out:
# <AxesSubplot:xlabel='sale_date'>

# %%
y.resample('m').mean().plot()
# Out:
# <AxesSubplot:xlabel='sale_date'>

# %%
y.resample('w').mean().plot()
# Out:
# <AxesSubplot:xlabel='sale_date'>

# %%
y.resample('m').mean().diff().plot()
# Out:
# <AxesSubplot:xlabel='sale_date'>

# %%
y.groupby([y.index.year]).mean()
# Out:
# sale_date
# 2013    233.966480
# 2014    269.111126
# 2015    280.971482
# Name: sales_total, dtype: float64

# %%
y.groupby([y.index.year]).mean().plot()
# Out:
# <AxesSubplot:xlabel='sale_date'>

# %%
y.groupby([y.index.year,y.index.month]).mean()
# Out:
# sale_date  sale_date
# 2013       1            157.894723
#            2            176.411855
#            3            214.181650
#            4            244.460082
#            5            264.663123
#            6            285.261279
#            7            296.881241
#            8            266.183375
#            9            247.237694
#            10           227.868064
#            11           248.108656
#            12           175.753692
# 2014       1            182.410791
#            2            203.207122
#            3            244.488991
#            4            282.786091
#            5            306.267538
#            6            324.965376
#            7            342.849100
#            8            307.345466
#            9            281.350430
#            10           263.133772
#            11           286.821036
#            12           200.538977
# 2015       1            191.725206
#            2            211.589839
# ...

# %%
y.groupby([y.index.year,y.index.month]).mean().plot()
# Out:
# <AxesSubplot:xlabel='sale_date,sale_date'>

# %%
y.groupby([y.index.year,y.index.month]).mean().unstack(0).plot()
# Out:
# <AxesSubplot:xlabel='sale_date'>

# %%
y.head()
# Out:
# sale_date
# 2013-01-01     10.92
# 2013-01-01    218.40
# 2013-01-01    125.55
# 2013-01-01    453.60
# 2013-01-01    294.00
# Name: sales_total, dtype: float64

# %%
plt.scatter(y, y.shift(-1))
